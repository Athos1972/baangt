# %%
l_string = """
if (GlobalVariable.zu_hh_art != '') {
    if (WebUI.verifyElementPresent(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_basis'), 
        1, FailureHandling.OPTIONAL)) {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_basis'))
    }
    
    if (WebUI.verifyElementPresent(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_plus'), 
        1, FailureHandling.OPTIONAL)) {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_plus'))
    }
    
    if (WebUI.verifyElementPresent(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_extra'), 
        1, FailureHandling.OPTIONAL)) {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_extra'))
    }
    
    if (GlobalVariable.zu_hh_art == 'Basis') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_value_basis'))
    }
    
    if (GlobalVariable.zu_hh_art == 'Extra') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_value_extra'))
    }
    
    if (GlobalVariable.zu_hh_art == 'Plus') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_value_plus'))
    }
}

if (GlobalVariable.zu_hh_create == 'X') {
    if (GlobalVariable.Mandant == 'DON') {
        if (GlobalVariable.zu_hh_art == 'Basis') {
            WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_Zusatzdeckung-expansion_BASIS'))
        } else {
            WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_Zusatzdeckung-expansion_PLUS'))
        }
    } else {
        if (GlobalVariable.zu_hh_art == 'Basis') {
            WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_Zusatzdeckung-expansion_BASIS'))
        } else {
            WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/wstv_hh_Zusatzdeckung-expansion_EXTRA'))
        }
    }
	
	WebUI.delay(1) //Chrome...
    
    if (GlobalVariable.zu_hh_hochwasser == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_hochwasser_checkbox'))
    }
    
    if (GlobalVariable.zu_hh_hochw_erhvar.toString().length() > 0) {
        if (GlobalVariable.zu_hh_art == 'Basis') {
            WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_hochwasser_erh_dropdown_basis'))
        } else {
            WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_hochwasser_erh_dropdown'))
        }
        
        switch (GlobalVariable.zu_hh_hochw_erhvar) {
            case 'Erh 1':
                WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_hochwasser_erh_erh1'))
                break
            case 'Erh 2':
                WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_hochwasser_erh_erh2'))
                break
            case 'Erh 3':
                WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_hochwasser_erh_erh3'))
                break
        }
    }
    
    if (GlobalVariable.zu_hh_erdbeben == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_erdbeben'))
    }
    
    if (GlobalVariable.zu_hh_erdb_erhvar.toString().length() > 0) {
        if (GlobalVariable.zu_hh_art == 'Basis') {
			//hier war doubleClick lange zeit OK. Jetzt (4.8.19) macht er bei DoubleClick das Dropdown wieder zu.
			//umgestellt auf Click
			//Könnte damit zusammenhängen, ob davor Hochwasser verwendet wird (Wenn ja-->doubleClick, wenn nein-->click. Beobachten...)
            WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_erdbeben_erh_dropdown_basis'))
        } else {
            WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_erdbeben_erh_dropdown'))
        }
        
        switch (GlobalVariable.zu_hh_erdb_erhvar) {
            case 'Erh 1':
                WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_erdbeben_erh_erh1'))
                break
            case 'Erh 2':
                WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_erdbeben_erh_erh2'))
                break
            case 'Erh 3':
                WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_erdbeben_erh_erh3'))
                break
        }
    }
    
    if ((GlobalVariable.zu_hh_geld == 'X') && (GlobalVariable.zu_hh_art != 'Basis')) {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_geld'))
    } else if (GlobalVariable.zu_hh_geld == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_geld_basis'))
    }
    
    if ((GlobalVariable.zu_hh_schmuck == 'X') && (GlobalVariable.zu_hh_art != 'Basis')) {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_schmuck'))
    } else if (GlobalVariable.zu_hh_schmuck == 'X') {
		WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_schmuck_basis'))
    }
    
    if (GlobalVariable.zu_hh_wertsachen == 'X') {
		if (GlobalVariable.zu_hh_art != 'Basis') {
			WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_wertsachen')) 
			WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_wertsachen_wert'), GlobalVariable.zu_hh_wert_wert)
		}
		else {
			WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_wertsachen_basis'))
			WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_wertsachen_wert_basis'), GlobalVariable.zu_hh_wert_wert)
		}

    }
    
    if ((GlobalVariable.zu_hh_panzerk == 'X') && (GlobalVariable.zu_hh_art != 'Basis')) {
        WebUI.scrollToElement(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_panzerkassen'), 
            1)

        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_panzerkassen'))

        WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_panzerkassen_wert'), GlobalVariable.zu_hh_panzk_wert)
    } else if (GlobalVariable.zu_hh_panzerk == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_panzerkassen_basis'))

        WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_panzerkassen_wert_basis'), 
            GlobalVariable.zu_hh_panzk_wert)
    }
    
    if (GlobalVariable.zu_hh_elektronik == 'X') {
		if (GlobalVariable.zu_hh_art != 'Basis') {
			WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_elektronik'))
		} else {
			WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_elektronik_basis'))
		}
    }
    
    if ((GlobalVariable.zu_hh_sport_jagd == 'X') && (GlobalVariable.zu_hh_art != 'Basis')) {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_sport_jagd'))
    } else if (GlobalVariable.zu_hh_sport_jagd == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_sport_jagd_basis'))
    }
    
    if ((GlobalVariable.zu_hh_sport_wert != '') && (GlobalVariable.zu_hh_art != 'Basis')) {
        WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_sport_jagd_wert'), GlobalVariable.zu_hh_sport_wert)
    } else if (GlobalVariable.zu_hh_sport_wert != '') {
        WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_sport_jagd_wert_basis'), 
            GlobalVariable.zu_hh_sport_wert)
    }
    
    if (GlobalVariable.zu_hh_unbenannte == 'X' && (GlobalVariable.zu_hh_art != 'Basis')) {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_unbenannte'))
    } else if (GlobalVariable.zu_hh_unbenannte == 'X') {
		WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_unbenannte_basis'))
    }
    
    if ((GlobalVariable.zu_hh_sos == 'X') && (GlobalVariable.zu_hh_art != 'Basis')) {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_sos'))
    } else if (GlobalVariable.zu_hh_sos == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_sos_basis'))
    }
    
    if (GlobalVariable.zu_hh_privhaftpfl == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_privhaftpfl_zus_person'))

        WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_privhaftpfl_zus_person_count'), 
            GlobalVariable.zu_hh_prihaftpf_person_count)

        WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/don_hh_privhaftpfl_zus_person_names'), 
            GlobalVariable.zu_hh_prihaftpf_person_name)
    }
    
    if (GlobalVariable.zu_hh_rasche_hilfe == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/wstv_hh_rasche_hilfe'), FailureHandling.STOP_ON_FAILURE)
    }
    
    if (GlobalVariable.zu_hh_tiefkuehl == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/wstv_hh_tiefkuehl'), FailureHandling.STOP_ON_FAILURE)
    }
    
    if (GlobalVariable.zu_hh_freizeitpaket == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/wstv_hh_freizeitpaket'), FailureHandling.STOP_ON_FAILURE)
    }
    
    if ((GlobalVariable.zu_hh_freizeit_wert != '') && (GlobalVariable.zu_hh_art != 'Basis')) {
        WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/wstv_hh_freizeit_wert'), GlobalVariable.zu_hh_freizeit_wert)
    } else if (GlobalVariable.zu_hh_freizeit_wert != '') {
        WebUI.setText(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/wstv_hh_freizeit_wert_basis'), 
            GlobalVariable.zu_hh_freizeit_wert)
    }
    
    if (GlobalVariable.zu_hh_erw_premium == 'X') {
        WebUI.click(findTestObject('Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/wstv_hh_erw_premium'), FailureHandling.STOP_ON_FAILURE)
    }
}


"""

# %%
l_string = l_string.replace(") {", "")
l_string = l_string.replace("((GlobalVariable.", "self.testcaseDataDict['")
l_string = l_string.replace("WebUI.click(findTestObject(", "self.browserSession.findByAndClick(xpath=")
l_string = l_string.replace("WebUI.verifyElementPresent(findTestObject(", "self.browserSession.findBy(xpath='")
l_string = l_string.replace("GlobalVariable.", "self.testcaseDataDict['")
l_string = l_string.replace("WebUI.setText(findTestObject(", "self.browserSession.findByAndSetText(xpath='")
l_string = l_string.replace("if (", "if ")
l_string = l_string.replace(" ==", "'] ==")
l_string = l_string.replace(" !=", "'] !=")
l_string = l_string.replace(" && ", " and ")
l_string = l_string.replace("else", "else:")
l_string = l_string.replace("{", "")
l_string = l_string.replace("}", "")
l_string = l_string.replace("))", ")")

l_lines = l_string.split("\n")
l_string = ""
for l_line in l_lines:
    if "if " in l_line:
        l_line = l_line + ":"
    l_string = l_string + "\n" + l_line
    
l_string = l_string.replace("else if", "elif")

print(l_string)
# Out:
# if self.testcaseDataDict['zu_hh_art'] != '':
#     if self.browserSession.findBy(xpath=''Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_basis'), :
#         1, FailureHandling.OPTIONAL)
#         self.browserSession.findByAndClick(xpath='Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_basis')
#
#
#     if self.browserSession.findBy(xpath=''Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_plus'), :
#         1, FailureHandling.OPTIONAL)
#         self.browserSession.findByAndClick(xpath='Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_plus')
#
#
#     if self.browserSession.findBy(xpath=''Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_extra'), :
#         1, FailureHandling.OPTIONAL)
#         self.browserSession.findByAndClick(xpath='Page_VIGO Wohnen/Deckungen/Haushalt_zusatzdeckungen/hh_combobox_extra')
#
#
#     if self.testcaseDataDict['zu_hh_art'] == 'Basis':
# ...
